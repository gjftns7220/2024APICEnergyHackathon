# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score


data_path = 'final_merged_base_alberta_wildfire_with_gas_and_pipes_summary.csv'
df = pd.read_csv(data_path)
df['Year'] = pd.to_datetime(df['Month']).dt.year
df['Month'] = pd.to_datetime(df['Month']).dt.month

features = [
    'A', 'B', 'C', 'D', 'E',
    'Year', 'Month',
    'Gas Plant Frac', 'Gas Plant Sweet', 'Gp Acid Gas Flaring',
    'Gp Acid Gas Flaring%', 'Gp Acid Gas Inj', 'Gp Mainline Strdle',
    'Gp Sulphur Rcvry', 'Avg Capacity (1000 m3/d)'
]


for feature in features:
    if df[feature].dtype == object:
        df[feature] = df[feature].str.replace(',', '').astype(float)


scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df[features + ['prod_%_diff']])
df_scaled = pd.DataFrame(df_scaled, columns=features + ['prod_%_diff'], index=df.index)

train_indices = df[(df['Year'] < 2018) | ((df['Year'] == 2018) & (df['Month'] <= 10))].index
test_indices = df[((df['Year'] == 2018) & (df['Month'] >= 11)) | (df['Year'] > 2018)].index

X_train = df_scaled.loc[train_indices, features].values.reshape((-1, 1, len(features)))
y_train = df_scaled.loc[train_indices, 'prod_%_diff'].values
X_test = df_scaled.loc[test_indices, features].values.reshape((-1, 1, len(features)))
y_test = df_scaled.loc[test_indices, 'prod_%_diff'].values

model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(1, len(features))))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=2)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Test MSE: {mse}")
print(f"Test R-squared: {r2}")
# Out:
# Epoch 1/100
# 5/5 - 1s - loss: 0.2127 - val_loss: 0.2213 - 1s/epoch - 224ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.1852 - val_loss: 0.1916 - 28ms/epoch - 6ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.1589 - val_loss: 0.1639 - 29ms/epoch - 6ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.1350 - val_loss: 0.1377 - 27ms/epoch - 5ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.1133 - val_loss: 0.1144 - 28ms/epoch - 6ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.0962 - val_loss: 0.0946 - 29ms/epoch - 6ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.0829 - val_loss: 0.0795 - 28ms/epoch - 6ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.0743 - val_loss: 0.0689 - 27ms/epoch - 5ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.0696 - val_loss: 0.0619 - 27ms/epoch - 5ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.0647 - val_loss: 0.0572 - 27ms/epoch - 5ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.0599 - val_loss: 0.0535 - 25ms/epoch - 5ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.0555 - val_loss: 0.0503 - 26ms/epoch - 5ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.0513 - val_loss: 0.0476 - 26ms/epoch - 5ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.0480 - val_loss: 0.0453 - 27ms/epoch - 5ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.0448 - val_loss: 0.0435 - 29ms/epoch - 6ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.0423 - val_loss: 0.0421 - 27ms/epoch - 5ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.0400 - val_loss: 0.0415 - 26ms/epoch - 5ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.0382 - val_loss: 0.0412 - 26ms/epoch - 5ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.0367 - val_loss: 0.0412 - 28ms/epoch - 6ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.0355 - val_loss: 0.0413 - 35ms/epoch - 7ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.0346 - val_loss: 0.0416 - 29ms/epoch - 6ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.0338 - val_loss: 0.0418 - 28ms/epoch - 6ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.0333 - val_loss: 0.0423 - 29ms/epoch - 6ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.0327 - val_loss: 0.0428 - 27ms/epoch - 5ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.0324 - val_loss: 0.0437 - 27ms/epoch - 5ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.0321 - val_loss: 0.0442 - 26ms/epoch - 5ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.0317 - val_loss: 0.0446 - 27ms/epoch - 5ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.0315 - val_loss: 0.0450 - 29ms/epoch - 6ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.0314 - val_loss: 0.0453 - 27ms/epoch - 5ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.0312 - val_loss: 0.0446 - 27ms/epoch - 5ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.0309 - val_loss: 0.0442 - 27ms/epoch - 5ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.0308 - val_loss: 0.0438 - 27ms/epoch - 5ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.0307 - val_loss: 0.0437 - 27ms/epoch - 5ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.0305 - val_loss: 0.0434 - 27ms/epoch - 5ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.0304 - val_loss: 0.0438 - 28ms/epoch - 6ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.0303 - val_loss: 0.0443 - 36ms/epoch - 7ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.0301 - val_loss: 0.0445 - 28ms/epoch - 6ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.0300 - val_loss: 0.0444 - 28ms/epoch - 6ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.0299 - val_loss: 0.0435 - 27ms/epoch - 5ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.0298 - val_loss: 0.0436 - 28ms/epoch - 6ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.0297 - val_loss: 0.0437 - 29ms/epoch - 6ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.0295 - val_loss: 0.0436 - 32ms/epoch - 6ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.0295 - val_loss: 0.0442 - 30ms/epoch - 6ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.0293 - val_loss: 0.0446 - 25ms/epoch - 5ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.0293 - val_loss: 0.0442 - 27ms/epoch - 5ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.0291 - val_loss: 0.0445 - 26ms/epoch - 5ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.0290 - val_loss: 0.0445 - 27ms/epoch - 5ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.0289 - val_loss: 0.0441 - 28ms/epoch - 6ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.0288 - val_loss: 0.0441 - 30ms/epoch - 6ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.0288 - val_loss: 0.0440 - 29ms/epoch - 6ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.0287 - val_loss: 0.0442 - 30ms/epoch - 6ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.0287 - val_loss: 0.0442 - 30ms/epoch - 6ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.0286 - val_loss: 0.0442 - 29ms/epoch - 6ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.0285 - val_loss: 0.0435 - 27ms/epoch - 5ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.0284 - val_loss: 0.0438 - 28ms/epoch - 6ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.0283 - val_loss: 0.0440 - 27ms/epoch - 5ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.0283 - val_loss: 0.0447 - 61ms/epoch - 12ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.0282 - val_loss: 0.0451 - 35ms/epoch - 7ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.0282 - val_loss: 0.0451 - 33ms/epoch - 7ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0281 - val_loss: 0.0448 - 35ms/epoch - 7ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0280 - val_loss: 0.0447 - 29ms/epoch - 6ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.0279 - val_loss: 0.0442 - 29ms/epoch - 6ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0279 - val_loss: 0.0440 - 27ms/epoch - 5ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0279 - val_loss: 0.0442 - 28ms/epoch - 6ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.0278 - val_loss: 0.0443 - 28ms/epoch - 6ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.0278 - val_loss: 0.0441 - 27ms/epoch - 5ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.0277 - val_loss: 0.0440 - 30ms/epoch - 6ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0277 - val_loss: 0.0439 - 30ms/epoch - 6ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0276 - val_loss: 0.0437 - 27ms/epoch - 5ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0276 - val_loss: 0.0435 - 28ms/epoch - 6ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0275 - val_loss: 0.0439 - 28ms/epoch - 6ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0275 - val_loss: 0.0441 - 29ms/epoch - 6ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0275 - val_loss: 0.0440 - 29ms/epoch - 6ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0274 - val_loss: 0.0438 - 29ms/epoch - 6ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0274 - val_loss: 0.0440 - 26ms/epoch - 5ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.0274 - val_loss: 0.0438 - 26ms/epoch - 5ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0274 - val_loss: 0.0441 - 28ms/epoch - 6ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.0273 - val_loss: 0.0438 - 25ms/epoch - 5ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.0273 - val_loss: 0.0443 - 27ms/epoch - 5ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.0272 - val_loss: 0.0439 - 27ms/epoch - 5ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.0272 - val_loss: 0.0438 - 26ms/epoch - 5ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0434 - 26ms/epoch - 5ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.0272 - val_loss: 0.0435 - 27ms/epoch - 5ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0431 - 29ms/epoch - 6ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0427 - 28ms/epoch - 6ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0426 - 27ms/epoch - 5ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0429 - 27ms/epoch - 5ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0270 - val_loss: 0.0435 - 27ms/epoch - 5ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.0270 - val_loss: 0.0441 - 26ms/epoch - 5ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.0270 - val_loss: 0.0437 - 27ms/epoch - 5ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0269 - val_loss: 0.0432 - 26ms/epoch - 5ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.0269 - val_loss: 0.0432 - 25ms/epoch - 5ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.0269 - val_loss: 0.0432 - 26ms/epoch - 5ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.0268 - val_loss: 0.0432 - 26ms/epoch - 5ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.0269 - val_loss: 0.0425 - 27ms/epoch - 5ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.0268 - val_loss: 0.0428 - 27ms/epoch - 5ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0267 - val_loss: 0.0428 - 27ms/epoch - 5ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.0267 - val_loss: 0.0426 - 27ms/epoch - 5ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.0267 - val_loss: 0.0425 - 26ms/epoch - 5ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.0267 - val_loss: 0.0423 - 27ms/epoch - 5ms/step
# 2/2 [==============================] - 0s 2ms/step
# Test MSE: 0.042265639636478634
# Test R-squared: 0.007060681096083932

# %%
print("Train DataFrame shape:", train_df_scaled.shape)
print("Test DataFrame shape:", test_df_scaled.shape)
# Out:
# Train DataFrame shape: (0, 16)
# Test DataFrame shape: (36, 16)
